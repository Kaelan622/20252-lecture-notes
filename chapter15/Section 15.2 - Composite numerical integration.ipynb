# %% [markdown]
# ---
# Some useful $\LaTeX$ commands are defined in this cell:
# $$
# \newcommand{\abs}[1]{\left\lvert#1\right\rvert}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\set}[1]{\left\{#1\right\}}
# \newcommand{\paren}[1]{\left(#1\right)}
# \newcommand{\brack}[1]{\left[#1\right]}
# \newcommand{\ip}[2]{\left\langle#1,#2\right\rangle}
# \DeclareMathOperator{\span}{span}
# \DeclareMathOperator{\fl}{fl}
# \abs{x}, \norm{x}, \set{x}, \paren{x}, \brack{x}, \ip{x}{y}, \span, \fl
# $$
#
# ---

# %% [markdown]
# ---
# # 15.2 Composite numerical integration
# ---

# %% [markdown]
# ## Composite quadrature methods
#
# We can obtain improved approximations of $\int_a^b f(x)\,dx$ by dividing the interval $[a,b]$ into $r$ equal subintervals:
#
# $$[t_0,t_1], \quad [t_1,t_2], \quad \ldots, \quad [t_{r-1},t_r],$$
#
# where $t_0 = a$ and $t_r = b$.  Then
#
# $$
# \int_a^b f(x)\,dx = \sum_{i=1}^r \int_{t_{i-1}}^{t_i} f(x)\,dx.
# $$
#
# The length of each subinterval is
#
# $$ h = \frac{b - a}{r},$$
#
# and $t_i = a + ih$, for $i = 0, 1, \ldots, r$.

# %% [markdown]
# ---

# %% [markdown]
# ### Composite midpoint rule
#
# From the midpoint rule for the $i^{\mathrm{th}}$ interval $[t_{i-1},t_i]$, we have
#
# $$
# \begin{split}
# \int_{t_{i-1}}^{t_i} f(x)\,dx
# & = (t_i - t_{i-1})\,f\paren{\frac{t_{i-1} + t_i}{2}} + \frac{f''(\xi_i)}{24}(t_i - t_{i-1})^3 \\
# & = h f(a + (i - 1/2)h) + \frac{f''(\xi_i)}{24} h^3, \\
# \end{split}
# $$
#
# for some $\xi_i \in [t_{i-1},t_i]$.

# %% [markdown]
# Thus, we have:
#
# $$
# \begin{split}
# \int_a^b f(x)\,dx
# &= \sum_{i=1}^r \int_{t_{i-1}}^{t_i} f(x)\,dx \\
# &= \sum_{i=1}^r \brack{ h f(a + (i - 1/2)h) + \frac{f''(\xi_i)}{24} h^3 }\\
# &= h \sum_{i=1}^r f(a + (i - 1/2)h) + \paren{\frac{1}{r} \sum_{i=1}^r f''(\xi_i)} \frac{r h^3}{24} .\\
# \end{split}
# $$

# %% [markdown]
# By the **Intermediate Value Theorem**, there is a $\xi \in [a,b]$ such that
#
# $$f''(\xi) = \frac{1}{r} \sum_{i=1}^r f''(\xi_i).$$
#
# Therefore, we obtain the **composite midpoint rule**:
#
# $$
# \fbox{${\displaystyle
# \int_a^b f(x)\,dx = h \sum_{i=1}^r f(a + (i - 1/2)h) + \frac{f''(\xi)}{24} (b - a) h^2,
# \quad \xi \in [a,b],
# }$}
# $$
#
# which has **order two accuracy**:
#
# $$
# \fbox{${\displaystyle
# \abs{\int_a^b f(x)\,dx - h \sum_{i=1}^r f(a + (i - 1/2)h)} \leq \frac{\norm{f''}}{24} (b - a) h^2 = \mathcal{O}(h^2).
# }$}
# $$

# %% [markdown]
# ---
# ## Example
#
# $$
# \int_0^1 \paren{\frac{4}{1+x^2}} dx = \pi
# $$

# %%
using Printf

function midpointrule()
    a, b = 0., 1.
    f(x) = 4/(1 + x^2)
    intf = pi

    @printf "%5s %14s %12s %12s\n" "h" "approx" "error" "time"
    for r = [1e1 1e2 1e3 1e4 1e5 1e6 1e7]
        start = time()
        h = (b - a)/r

        # Using the Midpoint Rule        
        approx = h*sum(f(a + (i - 1/2)*h) for i=1:r)

        err = abs(intf - approx)
        @printf "%5.0e %14.10f %12.5e %12.8f\n" h approx err time()-start
    end
end
# Out:
# midpointrule (generic function with 1 method)

# %%
midpointrule()
# Out:
#     h         approx        error         time
# 1e-01   3.1424259850  8.33331e-04   0.00000000
# 1e-02   3.1416009869  8.33333e-06   0.00000000
# 1e-03   3.1415927369  8.33333e-08   0.00000000
# 1e-04   3.1415926544  8.33341e-10   0.00000000
# 1e-05   3.1415926536  8.36842e-12   0.00099993
# 1e-06   3.1415926536  2.88658e-14   0.00699997
# 1e-07   3.1415926536  6.21725e-14   0.06999993

# %% [markdown]
# ---

# %% [markdown]
# ### Composite trapezoidal rule
#
# From the trapezoidal rule for the $i^{\mathrm{th}}$ interval $[t_{i-1},t_i]$, we have
#
# $$
# \begin{split}
# \int_{t_{i-1}}^{t_i} f(x)\,dx
# & = \frac{t_i - t_{i-1}}{2}\brack{f(t_{i-1}) + f(t_i)} - \frac{f''(\xi_i)}{12}(t_i - t_{i-1})^3 \\
# & = \frac{h}{2}\brack{f(t_{i-1}) + f(t_i)} - \frac{f''(\xi_i)}{12}h^3 \\
# \end{split}
# $$
#
# for some $\xi_i \in [t_{i-1},t_i]$.

# %% [markdown]
# Thus, we have:
#
# $$
# \begin{split}
# \int_a^b f(x)\,dx
# &= \sum_{i=1}^r \int_{t_{i-1}}^{t_i} f(x)\,dx \\
# &= \sum_{i=1}^r \brack{ \frac{h}{2}\brack{f(t_{i-1}) + f(t_i)} - \frac{f''(\xi_i)}{12}h^3 }\\
# &= \frac{h}{2} \brack{f(t_0) + 2f(t_1) + \cdots + 2f(t_{r-1}) + f(t_r)} \\
# &\quad -  \frac{1}{r} \paren{\sum_{i=1}^r f''(\xi_i)} \frac{rh^3}{12}. \\
# \end{split}
# $$

# %% [markdown]
# Again, by the **Intermediate Value Theorem**, there is a $\xi \in [a,b]$ such that
#
# $$f''(\xi) = \frac{1}{r} \sum_{i=1}^r f''(\xi_i).$$
#
# Therefore, we obtain the **composite trapezoidal rule**:
#
# $$
# \fbox{${\displaystyle
# \int_a^b f(x)\,dx = \frac{h}{2}\brack{f(a) + 2 \sum_{i=1}^{r-1} f(a + ih) + f(b)} - \frac{f''(\xi)}{12} (b - a) h^2,
# \quad \xi \in [a,b],
# }$}
# $$
#
# which has **order two accuracy**:
#
# $$
# \fbox{${\displaystyle
# \abs{\int_a^b f(x)\,dx - \frac{h}{2}\brack{f(a) + 2 \sum_{i=1}^{r-1} f(a + ih) + f(b)}} \leq  \frac{\norm{f''}}{12} (b - a) h^2 = \mathcal{O}(h^2).
# }$}
# $$

# %% [markdown]
# ---
# ## Example
#
# The [error function](https://en.wikipedia.org/wiki/Error_function) is
#
# $$
# \mathrm{erf}(x) = \frac{2}{\sqrt{\pi}} \int_0^x e^{-t^2} dt.
# $$
#
# Thus,
#
# $$
# \int_0^1 e^{-x^2} dx = \frac{\sqrt{\pi}}{2}\mathrm{erf}(1).
# $$

# %%
import Pkg; Pkg.add("SpecialFunctions")
using SpecialFunctions

function traprule()
    a, b = 0., 1.
    f(x) = exp(-x^2)
    intf = √π/2*erf(1.)

    @printf "%5s %14s %12s %12s\n" "h" "approx" "error" "time"
    for r = [1e1 1e2 1e3 1e4 1e5 1e6 1e7]
        start = time()
        h = (b - a)/r

        # Using the Trapezoidal Rule
        approx = f(a)
        approx += 2*sum(f(a + i*h) for i=1:r-1)
        approx += f(b)
        approx *= h/2

        err = abs(intf - approx)
        @printf "%5.0e %14.10f %12.5e %12.8f\n" h approx err time()-start
    end
end
# Out:
#    Resolving package versions...
#     Updating `C:\Users\Kaelan\OneDrive - Northern Illinois University\Documents\GitHub\20252-lecture-notes\Project.toml`
#   [276daf66] + SpecialFunctions v2.5.0
#     Updating `C:\Users\Kaelan\OneDrive - Northern Illinois University\Documents\GitHub\20252-lecture-notes\Manifest.toml`
#   [05823500] ↑ OpenLibm_jll v0.8.1+2 ⇒ v0.8.1+4
#  project...ecompiling
#    2720.7 ms  ✓ SimpleUnPack
#    2100.5 ms  ✓ MuladdMacro
#    2097.0 ms  ✓ ConcreteStructs
#    2092.6 ms  ✓ ExprTools
#    2095.5 ms  ✓ IteratorInterfaceExtensions
#    2084.8 ms  ✓ ADTypes
#   ✓ UnPack
#    2587.7 ms  ✓ FunctionWrappers
#    2583.5 ms  ✓ OffsetArrays
#     806.9 ms  ✓ FastPower
# SIMDTypes✓
#     867.3 ms  ✓ DataValueInterfaces
#     862.8 ms  ✓ EnumX
#     845.1 ms  ✓ CompositionsBase
#    1005.7 ms  ✓ ManualMemory
#    1024.5 ms  ✓ InverseFunctions
#    1309.4 ms  ✓ FillArrays
#     637.8 ms  ✓ IfElse
#     592.4 ms  ✓ PackageExtensionCompat
#     658.9 ms  ✓ CommonWorldInvalidations
#     775.7 ms  ✓ Inflate
#     732.0 ms  ✓ FastClosures
#     928.8 ms  ✓ Adapt
#     967.7 ms  ✓ EnzymeCore
#     946.7 ms  ✓ ConstructionBase
#     944.2 ms  ✓ TruncatedStacktraces
#    1058.6 ms  ✓ CpuId
#    1140.7 ms  ✓ SimpleTraits
#    1308.6 ms  ✓ KLU
#    1547.0 ms  ✓ GenericSchur
#    1762.5 ms  ✓ FastLapackInterface
#     948.3 ms  ✓ oneTBB_jll
#    2213.1 ms  ✓ ChainRulesCore
# RuntimeGeneratedFunctions
#     632.2 ms  ✓ TableTraits
#    1402.8 ms  ✓ Pango_jll
#     940.9 ms  ✓ FunctionWrappersWrappers
#    1102.5 ms  ✓ Parameters
#    2947.3 ms  ✓ IntelOpenMP_jll
#    2019.1 ms  ✓ DifferentiationInterface
#    2502.2 ms  ✓ SparseMatrixColorings
#    1650.6 ms  ✓ FastPower → FastPowerForwardDiffExt
#     813.2 ms  ✓ InverseFunctions → InverseFunctionsDatesExt
#    1313.2 ms  ✓ InverseFunctions → InverseFunctionsTestExt
#    4275.2 ms  ✓ TimerOutputs
#    1768.0 ms  ✓ ThreadingUtilities
#    2245.4 ms  ✓ Sparspak
#     811.2 ms  ✓ CompositionsBase → CompositionsBaseInverseFunctionsExt
#     841.3 ms  ✓ LogExpFunctions → LogExpFunctionsInverseFunctionsExt
#    1377.8 ms  ✓ Unitful → InverseFunctionsUnitfulExt
#     806.1 ms  ✓ FillArrays → FillArraysStatisticsExt
#    1087.5 ms  ✓ FillArrays → FillArraysSparseArraysExt
#     924.7 ms  ✓ ArrayInterface
# OffsetArrays → OffsetArraysAdaptExt
#     934.3 ms  ✓ GPUArraysCore
#     853.8 ms  ✓ EnzymeCore → AdaptExt
#    1352.2 ms  ✓ Static
#     723.4 ms  ✓ ADTypes → ADTypesEnzymeCoreExt
#     706.4 ms  ✓ ConstructionBase → ConstructionBaseLinearAlgebraExt
#     739.7 ms  ✓ ADTypes → ADTypesConstructionBaseExt
#    1311.2 ms  ✓ Unitful → ConstructionBaseUnitfulExt
#    1266.3 ms  ✓ ChainRulesCore → ChainRulesCoreSparseArraysExt
#     987.7 ms  ✓ ADTypes → ADTypesChainRulesCoreExt
#    1421.0 ms  ✓ Tables
#    2173.8 ms  ✓ LogExpFunctions → LogExpFunctionsChainRulesCoreExt
#    2946.6 ms  ✓ SpecialFunctions → SpecialFunctionsChainRulesCoreExt
#    1057.4 ms  ✓ DifferentiationInterface → DifferentiationInterfaceChainRulesCoreExt
#    1551.5 ms  ✓ DifferentiationInterface → DifferentiationInterfaceForwardDiffExt
#    1010.3 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseArraysExt
#    3009.6 ms  ✓ MKL_jll
#    1583.5 ms  ✓ SparseMatrixColorings → SparseMatrixColoringsColorsExt
#    1106.2 ms  ✓ MaybeInplace
#    1530.3 ms  ✓ DifferentiationInterface → DifferentiationInterfaceSparseMatrixColoringsExt
#    1027.5 ms  ✓ ArrayInterface → ArrayInterfaceSparseArraysExt
#   14213.7 ms  ✓ Krylov
#    1112.7 ms  ✓ ArrayInterface → ArrayInterfaceChainRulesCoreExt
#     820.4 ms  ✓ ArrayInterface → ArrayInterfaceStaticArraysCoreExt
#     824.5 ms  ✓ SciMLStructures
#     815.2 ms  ✓ ArrayInterface → ArrayInterfaceGPUArraysCoreExt
#     794.9 ms  ✓ BitTwiddlingConvenienceFunctions
#    1624.6 ms  ✓ CPUSummary
#     845.2 ms  ✓ MaybeInplace → MaybeInplaceSparseArraysExt
#    1561.0 ms  ✓ Setfield
#    2547.3 ms  ✓ StaticArrayInterface
#    1327.1 ms  ✓ PreallocationTools
#    2811.1 ms  ✓ Accessors
#   ✓ HostCPUFeatures
#    1364.9 ms  ✓ PolyesterWeave
#   17219.9 ms  ✓ StaticArrays
#    1207.1 ms  ✓ FiniteDiff
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#    1254.3 ms  ✓ CloseOpenIntervals
#    1491.1 ms  ✓ LayoutPointers
#   11024.8 ms  ✓ Plots → UnitfulExt
#    1316.6 ms  ✓ Accessors → LinearAlgebraExt
#    1431.1 ms  ✓ Accessors → TestExt
#    1278.7 ms  ✓ Accessors → UnitfulExt
#    1193.6 ms  ✓ StaticArrays → StaticArraysStatisticsExt
#    1313.6 ms  ✓ StaticArrays → StaticArraysChainRulesCoreExt
#    2041.3 ms  ✓ ArnoldiMethod
#    1604.8 ms  ✓ ForwardDiff → ForwardDiffStaticArraysExt
#    1183.0 ms  ✓ Adapt → AdaptStaticArraysExt
#    1264.9 ms  ✓ ConstructionBase → ConstructionBaseStaticArraysExt
#    2704.4 ms  ✓ FastGaussQuadrature
#    1316.2 ms  ✓ DifferentiationInterface → DifferentiationInterfaceStaticArraysExt
#     881.1 ms  ✓ FiniteDiff → FiniteDiffSparseArraysExt
#    1372.3 ms  ✓ StaticArrayInterface → StaticArrayInterfaceStaticArraysExt
#    1389.5 ms  ✓ Accessors → StaticArraysExt
#    1294.5 ms  ✓ FiniteDiff → FiniteDiffStaticArraysExt
#     772.0 ms  ✓ DifferentiationInterface → DifferentiationInterfaceFiniteDiffExt
#    1693.5 ms  ✓ NLSolversBase
#    1783.3 ms  ✓ StrideArraysCore
#    2483.0 ms  ✓ SymbolicIndexingInterface
#    2836.2 ms  ✓ SciMLOperators
#    1875.0 ms  ✓ Polyester
#    3182.7 ms  ✓ LineSearches
#    1177.3 ms  ✓ SciMLOperators → SciMLOperatorsStaticArraysCoreExt
#    1432.9 ms  ✓ SciMLOperators → SciMLOperatorsSparseArraysExt
#    3991.4 ms  ✓ RecursiveArrayTools
#    1942.4 ms  ✓ FastBroadcast
#    1500.4 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsForwardDiffExt
#    1876.9 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsSparseArraysExt
#    2905.4 ms  ✓ RecursiveArrayTools → RecursiveArrayToolsFastBroadcastExt
#   39413.2 ms  ✓ MLStyle
#   39784.7 ms  ✓ ArrayLayouts
#    1285.0 ms  ✓ ArrayLayouts → ArrayLayoutsSparseArraysExt
#   24634.0 ms  ✓ Graphs
#    3176.2 ms  ✓ LazyArrays
#    1656.4 ms  ✓ VertexSafeGraphs
#    2165.5 ms  ✓ LazyArrays → LazyArraysStaticArraysExt
#   20837.6 ms  ✓ Expronicon
#   35093.5 ms  ✓ VectorizationBase
#    8994.7 ms  ✓ SparseDiffTools
#    1807.4 ms  ✓ SLEEFPirates
#    2257.4 ms  ✓ SparseDiffTools → SparseDiffToolsPolyesterExt
#  103922.1 ms  ✓ Polynomials
#   64146.2 ms  ✓ SciMLBase
#    1681.7 ms  ✓ Polynomials → PolynomialsChainRulesCoreExt
#    1658.5 ms  ✓ SciMLBase → SciMLBaseChainRulesCoreExt
#    2280.8 ms  ✓ SciMLBase → SciMLBasePyCallExt
#    4249.9 ms  ✓ SciMLJacobianOperators
#    8891.4 ms  ✓ LineSearch
#    2152.2 ms  ✓ LineSearch → LineSearchLineSearchesExt
#   21096.9 ms  ✓ DiffEqBase
#    2079.8 ms  ✓ DiffEqBase → DiffEqBaseSparseArraysExt
#    2137.6 ms  ✓ DiffEqBase → DiffEqBaseChainRulesCoreExt
#    2211.1 ms  ✓ DiffEqBase → DiffEqBaseUnitfulExt
#   19993.6 ms  ✓ NonlinearSolveBase
#    2090.0 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLineSearchExt
#    2552.1 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseMatrixColoringsExt
#    2487.7 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseSparseArraysExt
#    2880.1 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseDiffEqBaseExt
#    3048.3 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseForwardDiffExt
#   22709.8 ms  ✓ OrdinaryDiffEqCore
#    2886.6 ms  ✓ OrdinaryDiffEqCore → OrdinaryDiffEqCoreEnzymeCoreExt
#   13768.6 ms  ✓ OrdinaryDiffEqSymplecticRK
#   15174.3 ms  ✓ OrdinaryDiffEqExplicitRK
#  125209.1 ms  ✓ LoopVectorization
#    3311.1 ms  ✓ OrdinaryDiffEqFunctionMap
#   41908.7 ms  ✓ BracketingNonlinearSolve
#   22064.7 ms  ✓ OrdinaryDiffEqHighOrderRK
#    3786.0 ms  ✓ OrdinaryDiffEqPRK
#   ✓ OrdinaryDiffEqStabilizedRK
#   24654.2 ms  ✓ OrdinaryDiffEqSSPRK
#    4033.0 ms  ✓ OrdinaryDiffEqRKN
#    3007.6 ms  ✓ OrdinaryDiffEqQPRK
#    3748.9 ms  ✓ OrdinaryDiffEqFeagin
#    1563.6 ms  ✓ LoopVectorization → SpecialFunctionsExt
#   13689.5 ms  ✓ OrdinaryDiffEqLowOrderRK
#    1819.2 ms  ✓ LoopVectorization → ForwardDiffExt
#    1652.3 ms  ✓ TriangularSolve
#    2352.2 ms  ✓ BracketingNonlinearSolve → BracketingNonlinearSolveForwardDiffExt
#   50917.8 ms  ✓ NonlinearSolveSpectralMethods
#    2861.5 ms  ✓ NonlinearSolveSpectralMethods → NonlinearSolveSpectralMethodsForwardDiffExt
#    6359.9 ms  ✓ OrdinaryDiffEqAdamsBashforthMoulton
#    9283.7 ms  ✓ OrdinaryDiffEqLowStorageRK
#   25601.6 ms  ✓ OrdinaryDiffEqTsit5
#    2788.8 ms  ✓ OrdinaryDiffEqNordsieck
#   34190.7 ms  ✓ RecursiveFactorization
#   54245.3 ms  ✓ SimpleNonlinearSolve
#    3130.6 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveDiffEqBaseExt
#    3975.5 ms  ✓ SimpleNonlinearSolve → SimpleNonlinearSolveChainRulesCoreExt
#  255039.8 ms  ✓ ExponentialUtilities
#    2002.9 ms  ✓ ExponentialUtilities → ExponentialUtilitiesStaticArraysExt
#  159976.9 ms  ✓ OrdinaryDiffEqVerner
#    8255.4 ms  ✓ OrdinaryDiffEqLinear
#  128805.1 ms  ✓ LinearSolve
#    3967.2 ms  ✓ LinearSolve → LinearSolveRecursiveArrayToolsExt
#    4272.6 ms  ✓ LinearSolve → LinearSolveEnzymeExt
#    4559.9 ms  ✓ NonlinearSolveBase → NonlinearSolveBaseLinearSolveExt
#   10120.4 ms  ✓ OrdinaryDiffEqDifferentiation
#   23231.9 ms  ✓ OrdinaryDiffEqExtrapolation
#   51212.9 ms  ✓ NonlinearSolveQuasiNewton
#    8355.7 ms  ✓ NonlinearSolveQuasiNewton → NonlinearSolveQuasiNewtonForwardDiffExt
#   96411.5 ms  ✓ NonlinearSolveFirstOrder
#   87504.3 ms  ✓ OrdinaryDiffEqRosenbrock
#   27360.5 ms  ✓ NonlinearSolve
#   10341.2 ms  ✓ OrdinaryDiffEqNonlinearSolve
#   21834.3 ms  ✓ OrdinaryDiffEqIMEXMultistep
#   23300.3 ms  ✓ OrdinaryDiffEqStabilizedIRK
#   24303.7 ms  ✓ OrdinaryDiffEqPDIRK
#   26837.4 ms  ✓ OrdinaryDiffEqSDIRK
#   12442.4 ms  ✓ OrdinaryDiffEqExponentialRK
#   66058.3 ms  ✓ OrdinaryDiffEqFIRK
#   46215.6 ms  ✓ OrdinaryDiffEqBDF
#   56703.4 ms  ✓ OrdinaryDiffEqDefault
#   11618.8 ms  ✓ OrdinaryDiffEq
#   207 dependencies successfully precompiled in 657 seconds. 206 already precompiled.
# traprule (generic function with 1 method)

# %%
traprule()
# Out:
#     h         approx        error         time
# 1e-01   0.7462107961  6.13337e-04   0.00000000
# 1e-02   0.7468180015  6.13134e-06   0.00000000
# 1e-03   0.7468240715  6.13132e-08   0.00000000
# 1e-04   0.7468241322  6.13133e-10   0.00099993
# 1e-05   0.7468241328  6.13964e-12   0.00500011
# 1e-06   0.7468241328  4.34097e-14   0.05100012
# 1e-07   0.7468241328  7.90479e-14   0.55699992

# %% [markdown]
# ---

# %% [markdown]
# ### Composite Simpson rule
#
# The Simpson rule for the $k^{\mathrm{th}}$ _pair_ of intervals $[t_{2k-2},t_{2k}]$ gives us
#
# $$
# \begin{split}
# \int_{t_{2k-2}}^{t_{2k}} f(x)\,dx
# & = \frac{t_{2k} - t_{2k-2}}{6}\brack{f(t_{2k-2}) + 4f\paren{\frac{t_{2k-2} + t_{2k}}{2}} + f(t_{2k})} -\frac{f''''(\xi_k)}{90} \paren{\frac{t_{2k} - t_{2k-2}}{2}}^5 \\
# & = \frac{h}{3}\brack{f(t_{2k-2}) + 4f(t_{2k-1}) + f(t_{2k})} -\frac{f''''(\xi_k)}{90} h^5 \\
# \end{split}
# $$
#
# for some $\xi_k \in [t_{2k-2},t_{2k}]$.

# %% [markdown]
# Thus, we have ($r$ must be even):
#
# $$
# \begin{split}
# \int_a^b f(x)\,dx
# &= \sum_{k=1}^{r/2} \int_{t_{2k-2}}^{t_{2k}} f(x)\,dx \\
# &= \sum_{k=1}^{r/2} \brack{\frac{h}{3}\brack{f(t_{2k-2}) + 4f(t_{2k-1}) + f(t_{2k})} -\frac{f''''(\xi_k)}{90} h^5} \\
# &= \frac{h}{3} \brack{f(t_0) + 4f(t_1) + 2f(t_2) + \cdots + 2f(t_{r-2}) + 4f(t_{r-1}) + f(t_r) }
# \\
# & \qquad -\frac{1}{r/2}\paren{\sum_{k=1}^{r/2} f''''(\xi_k)} \frac{h^5}{90}\frac{r}{2}. \\
# \end{split}
# $$

# %% [markdown]
# Once more, by the **Intermediate Value Theorem**, there is a $\xi \in [a,b]$ such that
#
# $$f''''(\xi) = \frac{1}{r/2} \sum_{i=1}^{r/2} f''''(\xi_i).$$
#
# Therefore, we obtain the **composite Simpson rule**:
#
# $$
# \fbox{${\displaystyle
# \int_a^b f(x)\,dx = \frac{h}{3}\brack{f(a) + 4 \sum_{k=1}^{r/2} f(t_{2k-1}) + 2 \sum_{k=1}^{r/2-1} f(t_{2k}) + f(b)}
# - \frac{f''''(\xi)}{180} (b - a) h^4
# }$}
# $$
#
# for some $\xi \in [a,b]$, which has **order four accuracy**:
#
# $$
# \fbox{${\displaystyle
# \abs{\int_a^b f(x)\,dx - \frac{h}{3}\brack{f(a) + 4 \sum_{k=1}^{r/2} f(t_{2k-1}) + 2 \sum_{k=1}^{r/2-1} f(t_{2k}) + f(b)}} \leq
# \frac{\norm{f''''}}{180} (b - a) h^4 = \mathcal{O}(h^4).
# }$}
# $$

# %% [markdown]
# ---
# ## Example
#
# $$
# \int_0^1 e^x\,dx = e - 1
# $$

# %%
function simpsonrule()
    a, b = 0., 1.
    f(x) = exp(x)
    intf = exp(one(a)) - 1

    @printf "%5s %14s %12s %12s\n" "h" "approx" "error" "time"
    for r = [1e1 1e2 1e3 1e4 1e5]
        start = time()
        h = (b - a)/r

        # Using the Simpson Rule
        approx = f(a)
        approx += 4*sum(f(a + (2k-1)*h) for k=1:r/2)
        approx += 2*sum(f(a + (2k)*h) for k=1:r/2-1)
        #approx += 4f(a + (r-1)*h)
        approx += f(b)
        approx *= h/3

        err = abs(intf - approx)
        @printf "%5.0e %14.10f %12.5e %12.8f\n" h approx err time()-start
    end
end
# Out:
# simpsonrule (generic function with 1 method)

# %%
simpsonrule()
# Out:
#     h         approx        error         time
# 1e-01   1.7182827819  9.53466e-07   0.00000000
# 1e-02   1.7182818286  9.54592e-11   0.00000000
# 1e-03   1.7182818285  1.02141e-14   0.00000000
# 1e-04   1.7182818285  6.66134e-16   0.00000000
# 1e-05   1.7182818285  6.66134e-15   0.00499988

# %%
traprule()
# Out:
#     h         approx        error         time
# 1e-01   0.7462107961  6.13337e-04   0.00000000
# 1e-02   0.7468180015  6.13134e-06   0.00000000
# 1e-03   0.7468240715  6.13132e-08   0.00000000
# 1e-04   0.7468241322  6.13133e-10   0.00099993
# 1e-05   0.7468241328  6.13964e-12   0.00499988
# 1e-06   0.7468241328  4.34097e-14   0.07300019
# 1e-07   0.7468241328  7.90479e-14   0.50300002

# %%
midpointrule()
# Out:
#     h         approx        error         time
# 1e-01   3.1424259850  8.33331e-04   0.00000000
# 1e-02   3.1416009869  8.33333e-06   0.00000000
# 1e-03   3.1415927369  8.33333e-08   0.00000000
# 1e-04   3.1415926544  8.33341e-10   0.00000000
# 1e-05   3.1415926536  8.36842e-12   0.00000000
# 1e-06   3.1415926536  2.88658e-14   0.00500011
# 1e-07   3.1415926536  6.21725e-14   0.07399988

# %% [markdown]
# ---

# %% [markdown]
# ## Composite quadrature rules summary
#
# $$
# \begin{align}
# \\
# \int_a^b f(x)\,dx &= h \sum_{i=1}^r f(a + (i - 1/2)h) + \frac{f''(\xi)}{24} (b - a) h^2
#  \quad &\text{(Midpoint)} \\\\
# \int_a^b f(x)\,dx &= \frac{h}{2}\brack{f(a) + 2 \sum_{i=1}^{r-1} f(a + ih) + f(b)} - \frac{f''(\xi)}{12} (b - a) h^2
# \quad &\text{(Trapezoidal)} \\\\
# \int_a^b f(x)\,dx &= \frac{h}{3}\brack{f(a) + 4 \sum_{k=1}^{r/2} f(t_{2k-1}) + 2 \sum_{k=1}^{r/2-1} f(t_{2k}) + f(b)} - \frac{f''''(\xi)}{180} (b - a) h^4
# \quad &\text{(Simpson)} \\\\
# \end{align}
# $$
#
# In each case, $\xi$ is some unknown point in the interval $[a,b]$.

# %% [markdown]
# ---

# %% [markdown]
# ## Computational cost
#
# We measure the computational cost of a quadrature rule by counting the number of function evaluations required.
#
# As $h$ gets smaller, the number of subintervals $r$ gets larger.
#
# We can see from the above quadrature rules that we need:
#
# - $r$ function evaluations for the Midpoint rule;
# - $r + 1$ function evaluations for the Trapezoidal rule;
# - $r + 1$ function evaluations for the Simpson rule.
#
# Thus, the Simpson rule is the most efficient in terms of number of function evaluations versus the order of accuracy.

# %% [markdown]
# ---

# %% [markdown]
# ## Numerical integration of noisy data
#
# Numerical integration is not sensitive to random noise in the function values.
#
# Let
#
# $$f(x) = e^x \sin(3x).$$
#
# Then
#
# $$ \int_0^x f'(t)\, dt = f(x) - f(0) = f(x) . $$

# %%
using Plots, LaTeXStrings

f(x)  = exp(x)*(                sin(3x))
f1(x) = exp(x)*(  3cos(3x) +    sin(3x))

a, b, r = 0, 1, 200

xx = range(a, b, length=r)
h = xx[2] - xx[1]

yyp = f1.(xx)

yypn = yyp + randn(size(yyp))  # add noise to derivative values

# Using the composite trapezoid rule on the noisy data
yyn = h/2*[yypn[1] + 2*sum(yypn[2:k-1]) + yypn[k] for k=1:r]

yytrue = f.(xx)

plot(title="Noisy integration", legend=:bottomleft)
plot!(xx, yyp, label=L"f'(x)")
plot!(xx, yypn, label="Noisy derivative")
plot!(xx, yyn, label="Numerical integral of noisy derivative")
plot!(xx, yytrue, label=L"f(x)")

# %% [markdown]
# ---
